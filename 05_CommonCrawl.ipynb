# %% [markdown]
# ## CommonCrawl
#
# CommonCrawl is a publically accessible web crawl.
#
# It comprises ca. 250TB and 3 billion web pages, hosted on AWS S3 as a public dataset.

# %%
test_data = [
    'http://google.ch/maps/place',
    'https://maps.google.se/maps',
    'https://www.google.com.sg/maps/place/The+Herencia/@1.2924232,103.8388365,17z/data=!4m5!1m2!2m1!1s46+Kim+Yam+Road,+%2305-03The+Herencia,+Singapore+239351!3m1!1s0x31da1974c7afb233:0x67979b46ae734638',
    '<a href="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3324.0129670661863!2d-117.7320547847609!3d33.579012580737334!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x80dce8acf2f4fa83%3A0xe88f66f162179e44!2s120+Vantis+Dr+%23300%2C+Aliso+Viejo%2C+CA+92656!5e0!3m2!1sen!2sus!4v1515004788726">other stuff</a>',
    'http://maps.google.com/maps?f=q&source=s_q&hl=en&geocode=&q=3250+wilshire+blvd&sll=37.0625,-95.677068&sspn=76.898137,185.449219&ie=UTF8&hq=&hnear=3250+Wilshire+Blvd,+Los+Angeles,+California+90010&ll=34.061281,-118.293464&spn=0.010168,0.022638&z=16&iwloc=A'
    'https://www.google.de/maps/place/Stra%C3%9Fenbahnring+3/@53.5812503,9.9773535,17z/data=!3m1!4b1!4m2!3m1!1s0x47b18f4ad5b519b9:0x2d1c51827ac5ecfb',
    'https://www.google.ae/maps/place/Acorn+Strategy,+Marketing+and+Communications/@24.4199609,54.4395062,17z/data=!3m1!4b1!4m5!3m4!1s0x3e5e4273b83aaaab:0xfc6b9bfec5e761e6!8m2!3d24.419956!4d54.4416949?hl=en',
    'https://www.google.com/maps/embed?pb=!1m14!1m8!1m3!1d2370.03083612117!2d9.989029000000002!3d53.557216999999994!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x47b18f1792f86061%3A0x581b1e33bc4cb039!2sACG+audio+consulting+group+GmbH!5e0!3m2!1sde!2sde!4v1426080747695',
    'https://maps.google.com/maps?client=safari&oe=UTF-8&q=1307+W.+Morehead+St.+-+Suite+206Charlotte,+NC+28208&ie=UTF-8&hq=&hnear=0x8856a1d1ab1f8b3d:0xb3952553229945ef,1307+W+Morehead+St+%23206,+Charlotte,+NC+28208&gl=us&ei=aktKUqvoLKzD4APUvYDwAQ&ved=0CC0Q8gEwAA',
    '<iframe width="930" scrolling="no" height="350" frameborder="0" marginheight="0" marginwidth="0" src="https://maps.google.com/maps?f=q&amp;source=s_q&amp;hl=en&amp;geocode=&amp;q=4930+reed+road,+columbus,+ohio&amp;aq=&amp;sll=40.365277,-82.669252&amp;sspn=6.753944,9.558105&amp;ie=UTF8&amp;hq=&',
]

# %%
import re

RE_MAPS = re.compile('(https?://(?:(?:www\.)?google\.[^/]*/maps|maps\.google\.[^/]*|maps\.googleapis\.[^/]*)[^ <>"]*)')


def find_google_maps(unibody):
    """ find google maps links in the page HTML """
    return list(set(x for x in RE_MAPS.findall(unibody)
                    if 'sensor=true' not in x and 'geocode/json?' not in x))

# %%
from itertools import islice
import json

from warcio.archiveiterator import ArchiveIterator
import smart_open 
from tqdm import tqdm_notebook
import pandas as pd
from  w3lib.encoding import html_to_unicode

from html_to_etree import parse_html_bytes
from extract_social_media import find_links_tree


def process(url):
    """
    extract html responses from commoncrawl and extract social media links
    """
    warc_input = smart_open.smart_open(url) 

    records = ArchiveIterator(warc_input, arc2warc=True)
    for record in records: 
        if record.rec_type == 'response':
            content_type = record.http_headers.get_header('Content-Type')
            if 'text/html' not in content_type:
                continue
                
            uri = record.rec_headers.get_header('WARC-Target-URI')
            body = record.content_stream().read()
            
            unibody = html_to_unicode(content_type, body, default_encoding='utf8')[1]

            tree = parse_html_bytes(body, content_type)
            links = [x for x in set(find_links_tree(tree))
                     if x and len(x) < 100]
            yield {
                'uri': uri,
                'social_media': links,
                'google_maps': find_google_maps(unibody)
            }

# %%
SAMPLE_URL = 's3://commoncrawl/crawl-data/CC-NEWS/2018/04/CC-NEWS-20180405091124-00174.warc.gz'
recs = process(SAMPLE_URL)
recs = list(islice(tqdm_notebook(recs), 3000))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
with_maps = [r for r in recs if r['google_maps']]
print(json.dumps(with_maps, indent=4))

# https://github.com/aws-samples/pywren-workshops/blob/master/Lab-2-Common-Crawl/web_search.ipynb
# Out:
# [
#     {
#         "uri": "http://www.oregonwinepress.com/event-detail?eventTitle=the-brothers-reed-at-south-stage-cellars--1523430000--21952",
#         "social_media": [
#             "https://www.facebook.com/pages/Oregon-Wine-Press/56204313628",
#             "https://www.instagram.com/oregonwinepress/",
#             "https://twitter.com/oregonwinepress"
#         ],
#         "google_maps": [
#             "http://maps.google.com/maps?f=q&#38;source=s_q&#38;hl=en&#38;geocode=&#38;iwloc=&#38;q=125+S+3rd+Street,+Jacksonville,+OR,+97530,+United+States,&#38;ie=UTF8&#38;hq=&#38;hnear=125+S+3rd+Street,+Jacksonville,+OR,+97530,+United+States,&#38;z=14&#38;output=embed",
#             "http://maps.google.com/maps?q=125"
#         ]
#     },
#     {
#         "uri": "https://www.webnewswire.com/2018/04/05/rea-associates-announces-its-new-website/",
#         "social_media": [],
#         "google_maps": [
#             "https://www.google.com/maps/place/Rea+%26+Associates/@41.67462,-81.3413647,17z/data=!3m1!4b1!4m5!3m4!1s0x0:0x6bd3a193334814fa!8m2!3d41.67462!4d-81.339176?hl=en"
#         ]
#     },
#     {
#         "uri": "https://www.webnewswire.com/2018/04/05/rea-associates-announces-a-new-edition-to-its-zanesville-office/",
#         "social_media": [],
#         "google_maps": [
#             "https://www.google.com/maps/place/Rea+%26+Associates+CPA+Firm/@39.9490399,-81.99945,15z/data=!4m5!3m4!1s0x0:0x21152a80553161fa!8m2!3d39.9490399!4d-81.99945"
#         ]
#     },
#     {
#         "uri": "https://www.webnewswire.com/2018/04/05/rasdale-stamp-company-to-attend-the-plymouth-stamp-show-2018-as-a-dealer/",
#         "social_media": [],
#         "google_maps": [
#             "https://www.google.com/maps/place/Rasdale+Stamp+Company/@41.816317,-87.9773567,17z/data=!3m1!4b1!4m5!3m4!1s0x0:0x4f0ef1314e1483cc!8m2!3d41.816317!4d-87.975168?hl=en"
#         ]
#     },
#     {
#         "uri": "https://www.badisches-tagblatt.de/artikel_ausgabe.php?func=baden_baden/00_20180405070600_136829136-Orientierung-im-Fokus.txt.pl",
#         "social_media": [
#             "https://www.facebook.com/BadischesTagblatt",
#             "https://twitter.com/share"
#         ],
#         "google_maps": [
#             "https://maps.google.com/?ie=UTF8&ll=48.7656400,8.2285242&spn=2.387707,4.943848&z=10"
#         ]
#     },
#     {
#         "uri": "http://www.1wrestling.com/2018/04/03/complete-impact-wrestling-event-schedule-for-wrestlecon/",
#         "social_media": [
#             "http://www.youtube.com/1wrestlingvideo",
#             "http://www.twitter.com/1wrestling"
#         ],
#         "google_maps": [
#             "https://maps.google.com/?q=New+Orleans+(1021+Convention+Center+Blvd&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=135+Saint+Charles+Ave&amp;entry=gmail&amp;source=g"
#         ]
#     },
#     {
#         "uri": "http://business.financialpost.com/pmn/business-pmn/calm-after-storm-asian-stocks-rebound-from-trade-war-fears",
#         "social_media": [
#             "https://www.linkedin.com/company/financial-post",
#             "https://twitter.com/financialpost",
#             "https://plus.google.com/108203735864152511987",
#             "http://www.facebook.com/FinancialPost",
#             "https://www.facebook.com/FinancialPost/",
#             "@financialpost",
#             "http://www.facebook.com/financialpost",
#             "http://twitter.com/financialpost"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://business.financialpost.com/pmn/business-pmn/canadians-in-silicon-valley-reflect-on-us-gun-culture-in-wake-of-youtube-shooting",
#         "social_media": [
#             "https://www.linkedin.com/company/financial-post",
#             "https://twitter.com/financialpost",
#             "https://plus.google.com/108203735864152511987",
#             "http://www.facebook.com/FinancialPost",
#             "https://www.facebook.com/FinancialPost/",
#             "@financialpost",
#             "http://www.facebook.com/financialpost",
#             "http://twitter.com/financialpost"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://business.financialpost.com/pmn/business-pmn/energy-environment-to-be-focus-of-trudeau-trip-to-western-canada",
#         "social_media": [
#             "https://www.linkedin.com/company/financial-post",
#             "https://twitter.com/financialpost",
#             "https://plus.google.com/108203735864152511987",
#             "http://www.facebook.com/FinancialPost",
#             "https://www.facebook.com/FinancialPost/",
#             "@financialpost",
#             "http://www.facebook.com/financialpost",
#             "http://twitter.com/financialpost"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://business.financialpost.com/executive/five-things-you-need-to-know-before-starting-your-work-day-on-april-5",
#         "social_media": [
#             "https://www.linkedin.com/company/financial-post",
#             "https://twitter.com/financialpost",
#             "https://plus.google.com/108203735864152511987",
#             "http://www.facebook.com/FinancialPost",
#             "https://www.facebook.com/FinancialPost/",
#             "@financialpost",
#             "http://www.facebook.com/financialpost",
#             "http://twitter.com/financialpost"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.birminghammail.co.uk/news/midlands-news/city-streets-missed-most-birminghams-14491847?utm_source=google_news&utm_medium=referral&utm_campaign=google_news&utm_content=sitemap",
#         "social_media": [
#             "https://github.com/ded/script.js",
#             "https://twitter.com/birmingham_live",
#             "https://www.facebook.com/birmingham.live",
#             "https://www.instagram.com/birmingham.live"
#         ],
#         "google_maps": [
#             "https://maps.google.com/?q=9%2F10%2F11%29+Rednal+Road&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=Kings+Norton.+12%29+Welches+Close&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=Kings+Norton.+2%29+Shenley+Fields+Road&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=1%29+Alcester+Road+South&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=7%29+Kingstanding+Road&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=Kings+Norton.+5%2F6%29+Harborne+Park+Road&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=4%29+Selly+Oak+Road&amp;entry=gmail&amp;source=g",
#             "https://maps.google.com/?q=8%29+Walmley+Road&amp;entry=gmail&amp;source=g"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/sports-pmn/golf-sports-pmn/ian-poulter-takes-a-harrowing-path-to-augusta-national",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "http://www.twitter.com/pnewberry1963",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.ellitoral.com.ar/nota/2018-4-5-4-0-0-ejercicios-en-el-embarazo-un-camino-al-bienestar",
#         "social_media": [
#             "https://www.facebook.com/dialog/feed",
#             "http://www.facebook.com/DiarioElLitoral",
#             "https://plus.google.com/u/0/117357468031386185472",
#             "http://www.pinterest.com/diarioellitoral",
#             "http://www.youtube.com/diarioellitoral",
#             "https://instagram.com/diarioellitoral",
#             "@DiarioElLitoral",
#             "http://twitter.com/DiarioElLitoral"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?sensor=false&key=AIzaSyDKBJ24Cy1R_oNnc8fE9QAMvgqyJYATCnI"
#         ]
#     },
#     {
#         "uri": "https://potomaclocal.com/2018/04/04/no-reason-alarmed-cell-phone-today-just-test/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+PotomacLocal+%28PotomacLocal.com%29",
#         "social_media": [
#             "https://www.facebook.com/PotomacLocal",
#             "https://twitter.com/PotomacLocal"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?key=AIzaSyAd_lgOAoZ8abjAGwCB1SUebfEtikt4uMg&callback=initMap"
#         ]
#     },
#     {
#         "uri": "https://www.augsburger-allgemeine.de/landsberg/Kacheln-in-Zinnoberrot-und-Avocadogruen-id50793011.html",
#         "social_media": [
#             "@az_augsburg"
#         ],
#         "google_maps": [
#             "https://www.google.com/maps/embed/v1/place?key=AIzaSyBilU7vT_OAVwqL0w1FIng4hRZml28el40&amp;q=48.429008,8.592260&amp;zoom=12&amp;maptype=roadmap"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/news-pmn/canada-news-pmn/in-the-news-today-april-4-2",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/sports-pmn/basketball-sports-pmn/east-field-is-set-west-race-still-has-much-to-decide",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.watson.ch/Schweiz/Ostschweiz/922475473------Generation-Ruecksitz----waechst-heran-------Gemeinde-richtet-Haltestelle-fuer---Eltern-Taxis---ein",
#         "social_media": [
#             "@watson_news",
#             "https://twitter.com/ChristophBernet",
#             "https://www.facebook.com/watson.news"
#         ],
#         "google_maps": [
#             "https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1522.4978919034713!2d9.512196332681517!3d47.474472048801715!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x479b1a4c56949349%3A0xc628a6f7512bfe30!2sSchulhaus+Klosterguet!5e1!3m2!1sde!2sch!4v1522852135247"
#         ]
#     },
#     {
#         "uri": "https://potomaclocal.com/2018/04/04/sentara-hernia-surgery-kept-one-man-from-missing-his-workouts/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+PotomacLocal+%28PotomacLocal.com%29",
#         "social_media": [
#             "https://www.facebook.com/PotomacLocal",
#             "https://twitter.com/PotomacLocal"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?key=AIzaSyAd_lgOAoZ8abjAGwCB1SUebfEtikt4uMg&callback=initMap"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/news-pmn/iraq-leader-in-japan-for-talks-on-peace-reconstruction",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.augsburger-allgemeine.de/politik/Suedkorea-will-mit-Nordkorea-beim-Gipfel-nicht-ueber-Menschenrechte-sprechen-id42837286.html",
#         "social_media": [
#             "@az_augsburg"
#         ],
#         "google_maps": [
#             "https://www.google.com/maps/embed/v1/place?key=AIzaSyBilU7vT_OAVwqL0w1FIng4hRZml28el40&amp;q=Pj\u00f6ngjang,"
#         ]
#     },
#     {
#         "uri": "https://jungefreiheit.de/debatte/kommentar/2018/datenkrake-google/",
#         "social_media": [
#             "https://www.facebook.com/jungefreiheit",
#             "@junge_freiheit",
#             "https://twitter.com/Junge_Freiheit",
#             "https://www.youtube.com/feed/history/search_history",
#             "http://www.youtube.com/channel/UCXJBRgiZRZvfilIGQ4wN5CQ",
#             "https://www.youtube.com/channel/UCXJBRgiZRZvfilIGQ4wN5CQ"
#         ],
#         "google_maps": [
#             "https://www.google.com/maps/timeline"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/news-pmn/albanian-opposition-blocks-roads-in-anti-government-protest",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://www.veronasera.it/eventi/incontro-feltrinelli-luciano-canova-galileo-reloaded-6-aprile-2018-.html",
#         "social_media": [
#             "http://www.facebook.com/veronasera",
#             "http://twitter.com/veronasera"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?libraries=places&amp;key='"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/news-pmn/new-french-unrest-students-medics-protest-macron-reforms",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.ellitoral.com.ar/nota/2018-4-5-4-0-0-alberto-augusto-cejas",
#         "social_media": [
#             "https://www.facebook.com/dialog/feed",
#             "http://www.facebook.com/DiarioElLitoral",
#             "https://plus.google.com/u/0/117357468031386185472",
#             "http://www.pinterest.com/diarioellitoral",
#             "http://www.youtube.com/diarioellitoral",
#             "https://instagram.com/diarioellitoral",
#             "@DiarioElLitoral",
#             "http://twitter.com/DiarioElLitoral"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?sensor=false&key=AIzaSyDKBJ24Cy1R_oNnc8fE9QAMvgqyJYATCnI"
#         ]
#     },
#     {
#         "uri": "http://www.veronasera.it/eventi/pitecus-antonio-rezza-teatro-nuovo-7-aprile-2018-.html",
#         "social_media": [
#             "http://www.facebook.com/veronasera",
#             "http://twitter.com/veronasera"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?libraries=places&amp;key='"
#         ]
#     },
#     {
#         "uri": "http://www.veronasera.it/eventi/espana-te-quiero-cinema-alcione-film-8-aprile-11-maggio-2018-.html",
#         "social_media": [
#             "http://www.facebook.com/veronasera",
#             "http://twitter.com/veronasera"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?libraries=places&amp;key='"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/sports-pmn/gc2018-underway-duffy-gets-1st-gold-pearson-pulls-out",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "http://nationalpost.com/pmn/news-pmn/romania-9-dead-after-van-plunges-into-river",
#         "social_media": [
#             "https://www.facebook.com/NationalPost",
#             "@acoyne",
#             "https://twitter.com/nationalpost",
#             "https://www.pinterest.com/nationalpost/",
#             "http://twitter.com/nationalpost",
#             "@nationalpost",
#             "https://plus.google.com/+NationalPost",
#             "https://www.youtube.com/nationalpost",
#             "http://www.facebook.com/NationalPost",
#             "http://facebook.com/nationalpost",
#             "http://pinterest.com/nationalpost/",
#             "https://www.instagram.com/nationalpost/"
#         ],
#         "google_maps": [
#             "https://maps.google.com/maps/api/js?sensor=false&#038;libraries=places&#038;key=AIzaSyAhxjSYKbEZDd5TSkpV6vIX13poV2F84-4&#038;ver=4.9.5'"
#         ]
#     },
#     {
#         "uri": "https://www.augsburger-allgemeine.de/politik/Mit-seinen-Ideen-zum-Familiennachzug-veraergert-Seehofer-SPD-id42915776.html",
#         "social_media": [
#             "@az_augsburg"
#         ],
#         "google_maps": [
#             "https://www.google.com/maps/embed/v1/place?key=AIzaSyBilU7vT_OAVwqL0w1FIng4hRZml28el40&amp;q=Bundestag,"
#         ]
#     },
#     {
#         "uri": "http://www.veronasera.it/eventi/verona-doc-1-passeggiata-guidata-citta-14-aprile-2018-.html",
#         "social_media": [
#             "https://www.facebook.com/sorseggiandoverona/",
#             "http://www.facebook.com/veronasera",
#             "http://twitter.com/veronasera"
#         ],
#         "google_maps": [
#             "https://maps.googleapis.com/maps/api/js?libraries=places&amp;key='"
#         ]
#     }
# ]
